# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# citations:
# https://www.geeksforgeeks.org/data-analysis/exploratory-data-analysis-in-python/

# %%
TRAIN_PATH = "../2017_English_final/GOLD/Subtasks_CE/twitter-2016train-CE.txt"
VALIDATION_PATH="../2017_English_final/GOLD/Subtasks_CE/twitter-2016dev-CE.txt"
TEST_PATH="../2017_English_final/GOLD/Subtasks_CE/twitter-2016test-CE.txt"

# %% [markdown]
# load + small transformations for more readable dataset

# %%
headers=["id", "topic", "label","message"]


#load data
train_df = pd.read_csv(TRAIN_PATH, sep="\t", header=None, names=headers)
validation_df = pd.read_csv(VALIDATION_PATH, sep="\t", header=None, names=headers)
test_df = pd.read_csv(TEST_PATH, sep="\t", header=None, names=headers)

# %% [markdown]
# ## Get Basic information

# %%
print(train_df.shape)
print(validation_df.shape)
print(test_df.shape)
# Out:
# (5868, 4)
# (1967, 4)
# (20632, 4)

# %%
print(train_df.info())


merged_df = pd.concat([train_df, validation_df, test_df], ignore_index=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5868 entries, 0 to 5867
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       5868 non-null   int64
#  1   topic    5868 non-null   object
#  2   label    5868 non-null   int64
#  3   message  5868 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 183.5+ KB
# None

# %% [markdown]
# # EDA section
#
# do your eda here
# you probably want to create a copy of the dataset before making any transformations(so you dont have to reload the entire notebook if you make a mistake)
